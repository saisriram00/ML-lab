# %%
import csv
a = []
with open('id3.csv','r') as csvfile :
    for row in csv.reader(csvfile) :
        a.append(row)
    print(a)
print("\n The total number of training instances are : ",len(a))
num_attribute = len(a[0])-1
print("\n Initial hypothesis is: ")
hypothesis = ['0']*num_attribute
print(hypothesis)
for i in range(0,len(a)):
    if a[i][num_attribute] == 'yes':
        for j in range(0,num_attribute):
            if hypothesis[j] == '0' or hypothesis[j] == a[i][j] :
                hypothesis[j] = a[i][j]
            else :
                hypothesis[j] = '?'
            print("\n The hypothesis for training instance {} is \n" .format(i+1),hypothesis)
print("\n The maximally specific hypothesis for the training instance is")
print(hypothesis)
# Out:
# [['Outlook', 'Temperature', 'Humidity', 'Wind', 'Answer'], ['sunny', 'hot', 'high', 'weak', 'no'], ['sunny', 'hot', 'high', 'strong', 'no'], ['overcast', 'hot', 'high', 'weak', 'yes'], ['rain', 'mild', 'high', 'weak', 'yes'], ['rain', 'cool', 'normal', 'weak', 'yes'], ['rain', 'cool', 'normal', 'strong', 'no'], ['overcast', 'cool', 'normal', 'strong', 'yes'], ['sunny', 'mild', 'high', 'weak', 'no'], ['sunny', 'cool', 'normal', 'weak', 'yes'], ['rain', 'mild', 'normal', 'weak', 'yes'], ['sunny', 'mild', 'normal', 'strong', 'yes'], ['overcast', 'mild', 'high', 'strong', 'yes'], ['overcast', 'hot', 'normal', 'weak', 'yes'], ['rain', 'mild', 'high', 'strong', 'no']]
#
#  The total number of training instances are :  15
#
#  Initial hypothesis is:
# ['0', '0', '0', '0']
#
#  The hypothesis for training instance 4 is
#  ['overcast', '0', '0', '0']
#
#  The hypothesis for training instance 4 is
#  ['overcast', 'hot', '0', '0']
#
#  The hypothesis for training instance 4 is
#  ['overcast', 'hot', 'high', '0']
#
#  The hypothesis for training instance 4 is
#  ['overcast', 'hot', 'high', 'weak']
#
#  The hypothesis for training instance 5 is
#  ['?', 'hot', 'high', 'weak']
#
#  The hypothesis for training instance 5 is
#  ['?', '?', 'high', 'weak']
#
#  The hypothesis for training instance 5 is
#  ['?', '?', 'high', 'weak']
#
#  The hypothesis for training instance 5 is
#  ['?', '?', 'high', 'weak']
#
#  The hypothesis for training instance 6 is
#  ['?', '?', 'high', 'weak']
#
#  The hypothesis for training instance 6 is
#  ['?', '?', 'high', 'weak']
#
#  The hypothesis for training instance 6 is
#  ['?', '?', '?', 'weak']
#
#  The hypothesis for training instance 6 is
#  ['?', '?', '?', 'weak']
#
#  The hypothesis for training instance 8 is
#  ['?', '?', '?', 'weak']
#
#  The hypothesis for training instance 8 is
#  ['?', '?', '?', 'weak']
#
#  The hypothesis for training instance 8 is
#  ['?', '?', '?', 'weak']
#
#  The hypothesis for training instance 8 is
#  ['?', '?', '?', '?']
#
#  The hypothesis for training instance 10 is
#  ['?', '?', '?', '?']
#
#  The hypothesis for training instance 10 is
#  ['?', '?', '?', '?']
#
#  The hypothesis for training instance 10 is
#  ['?', '?', '?', '?']
#
#  The hypothesis for training instance 10 is
#  ['?', '?', '?', '?']
#
#  The hypothesis for training instance 11 is
#  ['?', '?', '?', '?']
#
#  The hypothesis for training instance 11 is
#  ['?', '?', '?', '?']
#
#  The hypothesis for training instance 11 is
#  ['?', '?', '?', '?']
#
#  The hypothesis for training instance 11 is
#  ['?', '?', '?', '?']
#
#  The hypothesis for training instance 12 is
#  ['?', '?', '?', '?']
#
#  The hypothesis for training instance 12 is
#  ['?', '?', '?', '?']
#
#  The hypothesis for training instance 12 is
#  ['?', '?', '?', '?']
#
#  The hypothesis for training instance 12 is
#  ['?', '?', '?', '?']
#
#  The hypothesis for training instance 13 is
#  ['?', '?', '?', '?']
#
#  The hypothesis for training instance 13 is
#  ['?', '?', '?', '?']
#
#  The hypothesis for training instance 13 is
#  ['?', '?', '?', '?']
#
#  The hypothesis for training instance 13 is
#  ['?', '?', '?', '?']
#
#  The hypothesis for training instance 14 is
#  ['?', '?', '?', '?']
#
#  The hypothesis for training instance 14 is
#  ['?', '?', '?', '?']
#
#  The hypothesis for training instance 14 is
#  ['?', '?', '?', '?']
#
#  The hypothesis for training instance 14 is
#  ['?', '?', '?', '?']
#
#  The maximally specific hypothesis for the training instance is
# ['?', '?', '?', '?']
